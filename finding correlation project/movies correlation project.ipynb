# %%
import pandas as pd
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt
import matplotlib.mlab as mlab
import matplotlib
plt.style.use('ggplot')
from matplotlib.pyplot import figure

# %matplotlib inline
matplotlib.rcParams['figure.figsize'] = (12,8)

pd.options.mode.chained_assignment = None

# %%
df=pd.read_csv("D:\data analysis\my work\portfolioproject\python project\movies.csv")
# Out:
# <>:1: SyntaxWarning: invalid escape sequence '\d'
# <>:1: SyntaxWarning: invalid escape sequence '\d'
# C:\Users\ahmed\AppData\Local\Temp\ipykernel_26556\735552859.py:1: SyntaxWarning: invalid escape sequence '\d'
#   df=pd.read_csv("D:\data analysis\my work\portfolioproject\python project\movies.csv")

# %%
df = pd.read_csv(r"D:\data analysis\my work\portfolioproject\python project\movies.csv")

# %%
for col in df.columns:  # Loop through all columns in the DataFrame
    pct_missing = np.mean(df[col].isnull())  # Calculate the percentage of missing values
    print('{} - {}%'.format(col, round(pct_missing * 100)))  # Print column name & missing percentage
# Out:
# name - 0%
# rating - 1%
# genre - 0%
# year - 0%
# released - 0%
# score - 0%
# votes - 0%
# director - 0%
# writer - 0%
# star - 0%
# country - 0%
# budget - 28%
# gross - 2%
# company - 0%
# runtime - 0%

# %%
df
# Out:
#                                                 name rating      genre  year  \
# 0                                        The Shining      R      Drama  1980
# 1                                    The Blue Lagoon      R  Adventure  1980
# 2     Star Wars: Episode V - The Empire Strikes Back     PG     Action  1980
# 3                                          Airplane!     PG     Comedy  1980
# 4                                         Caddyshack      R     Comedy  1980
# ...                                              ...    ...        ...   ...
# 7663                                    More to Life    NaN      Drama  2020
# 7664                                     Dream Round    NaN     Comedy  2020
# 7665                                   Saving Mbango    NaN      Drama  2020
# 7666                                    It's Just Us    NaN      Drama  2020
# 7667                                       Tee em el    NaN     Horror  2020
#
# ...

# %%
print(df.isnull().sum())  # Count missing values in each column
# Out:
# name           0
# rating        77
# genre          0
# year           0
# released       2
# score          3
# votes          3
# director       0
# writer         3
# star           1
# country        3
# budget      2171
# gross        189
# company       17
# runtime        4
# dtype: int64

# %%
df['rating'].fillna("Not Rated", inplace=True)  #Fill missing values with "Not Rated"
# Out:
# C:\Users\ahmed\AppData\Local\Temp\ipykernel_26556\2696999351.py:1: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# The behavior will change in pandas 3.0. This inplace method will never work because the intermediate object on which we are setting values always behaves as a copy.
#
# For example, when doing 'df[col].method(value, inplace=True)', try using 'df.method({col: value}, inplace=True)' or df[col] = df[col].method(value) instead, to perform the operation inplace on the original object.
#
#
#   df['rating'].fillna("Not Rated", inplace=True)  #Fill missing values with "Not Rated"

# %%
df['rating'].fillna("Not Rated", inplace=True)

# %%
plt.hist(df['budget'], bins=30, edgecolor='black', alpha=0.7)
plt.xlabel('Budget')
plt.ylabel('Frequency')
plt.title('Histogram of Budget')
plt.show()

# %%
df['budget'].fillna(df['budget'].median(), inplace=True)
# Out:
# C:\Users\ahmed\AppData\Local\Temp\ipykernel_26556\2169039485.py:1: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# The behavior will change in pandas 3.0. This inplace method will never work because the intermediate object on which we are setting values always behaves as a copy.
#
# For example, when doing 'df[col].method(value, inplace=True)', try using 'df.method({col: value}, inplace=True)' or df[col] = df[col].method(value) instead, to perform the operation inplace on the original object.
#
#
#   df['budget'].fillna(df['budget'].median(), inplace=True)

# %%
df.loc[:, 'budget'] = df['budget'].fillna(df['budget'].median())
#Ensures the change applies to the original DataFrame., No warnings about chained assignment.

# %%
df.loc[:, 'budget'] = df['budget'].fillna(df['budget'].median())
#Ensures the change applies to the original DataFrame., No warnings about chained assignment.

# %%
print(df.isnull().sum())  # Count missing values in each column
# Out:
# name          0
# rating        0
# genre         0
# year          0
# released      2
# score         3
# votes         3
# director      0
# writer        3
# star          1
# country       3
# budget        0
# gross       189
# company      17
# runtime       4
# dtype: int64

# %%
plt.hist(df['gross'], bins=30, edgecolor='black', alpha=0.7)
plt.xlabel('gross')
plt.ylabel('Frequency')
plt.title('Histogram of Budget')
plt.show()

# %%
df.loc[:, 'gross'] = df['gross'].fillna(df['gross'].median())
#Ensures the change applies to the original DataFrame., No warnings about chained assignment.

# %%
print(df.isnull().sum())  # Count missing values in each column
# Out:
# name         0
# rating       0
# genre        0
# year         0
# released     2
# score        3
# votes        3
# director     0
# writer       3
# star         1
# country      3
# budget       0
# gross        0
# company     17
# runtime      4
# dtype: int64

# %%
df['company'].fillna("Not Rated", inplace=True)  #Fill missing values with "Not Rated"
# Out:
# C:\Users\ahmed\AppData\Local\Temp\ipykernel_26556\173444692.py:1: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# The behavior will change in pandas 3.0. This inplace method will never work because the intermediate object on which we are setting values always behaves as a copy.
#
# For example, when doing 'df[col].method(value, inplace=True)', try using 'df.method({col: value}, inplace=True)' or df[col] = df[col].method(value) instead, to perform the operation inplace on the original object.
#
#
#   df['company'].fillna("Not Rated", inplace=True)  #Fill missing values with "Not Rated"

# %%
df.loc[:, 'company'] = df['company'].fillna("Not Rated")

# %%
plt.hist(df['runtime'], bins=30, edgecolor='black', alpha=0.7)
plt.xlabel('runtime')
plt.ylabel('Frequency')
plt.title('Histogram of runtime')
plt.show()

# %%
skewness = df['runtime'].skew()
print(skewness)
# Out:
# 2.09574340198209

# %%
df['runtime'].fillna(method='bfill', inplace=True)  #fill with last value
# Out:
# C:\Users\ahmed\AppData\Local\Temp\ipykernel_26556\3973225657.py:1: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# The behavior will change in pandas 3.0. This inplace method will never work because the intermediate object on which we are setting values always behaves as a copy.
#
# For example, when doing 'df[col].method(value, inplace=True)', try using 'df.method({col: value}, inplace=True)' or df[col] = df[col].method(value) instead, to perform the operation inplace on the original object.
#
#
#   df['runtime'].fillna(method='bfill', inplace=True)  #fill with last value
# C:\Users\ahmed\AppData\Local\Temp\ipykernel_26556\3973225657.py:1: FutureWarning: Series.fillna with 'method' is deprecated and will raise in a future version. Use obj.ffill() or obj.bfill() instead.
#   df['runtime'].fillna(method='bfill', inplace=True)  #fill with last value

# %%
df.fillna({'runtime': df['runtime'].bfill()}, inplace=True)

# %%
print(df.isnull().sum())  # Count missing values in each column
# Out:
# name        0
# rating      0
# genre       0
# year        0
# released    0
# score       0
# votes       0
# director    0
# writer      0
# star        0
# country     0
# budget      0
# gross       0
# company     0
# runtime     0
# dtype: int64

# %%
df.loc[:, 'country'] = df['country'].fillna("Not Rated")

# %%
# Fill NaN values in specific columns with "Not Rated"
df[['released', 'writer', 'star']] = df[['released', 'writer', 'star']].fillna("Not Rated")

# %%
plt.hist(df['votes'], bins=30, edgecolor='black', alpha=0.7)
plt.xlabel('votes')
plt.ylabel('Frequency')
plt.title('Histogram of Budget')
plt.show()

# %%
df.loc[:, 'votes'] = df['votes'].fillna(df['votes'].median())

# %%
df['gross'] = df['gross'].replace("gross", "not_rated")

# %%
df['score'] = df['score'].fillna(df['score'].median())

# %%
print(df.dtypes)
# Out:
# name         object
# rating       object
# genre        object
# year          int64
# released     object
# score       float64
# votes       float64
# director     object
# writer       object
# star         object
# country      object
# budget      float64
# gross       float64
# company      object
# runtime     float64
# dtype: object

# %%
df['budget'] = df['budget'].astype('int64')
df['gross'] = df['gross'].astype('int64')
df['votes'] = df['votes'].astype('int64')

# %%
df.drop_duplicates()
# Out:
#                                                 name     rating      genre  \
# 0                                        The Shining          R      Drama
# 1                                    The Blue Lagoon          R  Adventure
# 2     Star Wars: Episode V - The Empire Strikes Back         PG     Action
# 3                                          Airplane!         PG     Comedy
# 4                                         Caddyshack          R     Comedy
# ...                                              ...        ...        ...
# 7663                                    More to Life  Not Rated      Drama
# 7664                                     Dream Round  Not Rated     Comedy
# 7665                                   Saving Mbango  Not Rated      Drama
# 7666                                    It's Just Us  Not Rated      Drama
# 7667                                       Tee em el  Not Rated     Horror
#
#       year                          released  score      votes  \
# ...

# %%
df.sort_values(by=['gross'], inplace=False, ascending=False)
# Out:
#                                             name     rating   genre  year  \
# 5445                                      Avatar      PG-13  Action  2009
# 7445                           Avengers: Endgame      PG-13  Action  2019
# 3045                                     Titanic      PG-13   Drama  1997
# 6663  Star Wars: Episode VII - The Force Awakens      PG-13  Action  2015
# 7244                      Avengers: Infinity War      PG-13  Action  2018
# ...                                          ...        ...     ...   ...
# 3818                        Love, Honor and Obey          R  Comedy  2000
# 7625                            The Untold Story  Not Rated  Comedy  2019
# 7580                         Run with the Hunted  Not Rated   Crime  2019
# 2417                                    Madadayo  Not Rated   Drama  1993
# 3203                                  Trojan War      PG-13  Comedy  1997
#
#                                released  score       votes         director  \
# ...

# %%
plt.scatter(x=df['budget'],y=df['gross'])
plt.title('budget vs gross earnings')
plt.xlabel('gross earnings')
plt.ylabel('budget for a film')
plt.show()

# %%
sns.regplot(x='budget',y='gross',data=df,scatter_kws={"color":"red"},line_kws={"color":"green"})
# Out:
# <Axes: xlabel='budget', ylabel='gross'>

# %%
df.corr(method="pearson")
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[131], line 1
# ----> 1 df.corr(method="pearson")
#
# File D:\program files\anaconda\Lib\site-packages\pandas\core\frame.py:11049, in DataFrame.corr(self, method, min_periods, numeric_only)
#   11047 cols = data.columns
#   11048 idx = cols.copy()
# > 11049 mat = data.to_numpy(dtype=float, na_value=np.nan, copy=False)
#   11051 if method == "pearson":
#   11052     correl = libalgos.nancorr(mat, minp=min_periods)
#
# File D:\program files\anaconda\Lib\site-packages\pandas\core\frame.py:1993, in DataFrame.to_numpy(self, dtype, copy, na_value)
#    1991 if dtype is not None:
#    1992     dtype = np.dtype(dtype)
# -> 1993 result = self._mgr.as_array(dtype=dtype, copy=copy, na_value=na_value)
#    1994 if result.dtype is not dtype:
#    1995     result = np.asarray(result, dtype=dtype)
#
# ...

# %%
df_numeric = df.select_dtypes(include=['number'])  # Select only numeric columns
correlation_matrix = df_numeric.corr(method="pearson")
print(correlation_matrix)
# Out:
#              year     score     votes    budget     gross   runtime
# year     1.000000  0.098013  0.259504  0.291690  0.259504  0.120806
# score    0.098013  1.000000  0.185563  0.061931  0.185563  0.399338
# votes    0.259504  0.185563  1.000000  0.745881  1.000000  0.244308
# budget   0.291690  0.061931  0.745881  1.000000  0.745881  0.273183
# gross    0.259504  0.185563  1.000000  0.745881  1.000000  0.244308
# runtime  0.120806  0.399338  0.244308  0.273183  0.244308  1.000000

# %%
df_numeric = df.select_dtypes(include=['number'])  # Select only numeric columns
correlation_matrix = df_numeric.corr()
sns.heatmap(correlation_matrix,annot=True)
plt.title("correlation matrix for numeric features")
plt.xlabel("movie features")
plt.ylabel("movie features")
plt.show()

# %%
correlation_matrix = df.apply(lambda x: x.factorize()[0]).corr(method='pearson')

sns.heatmap(correlation_matrix, annot = True)

plt.title("Correlation matrix for Movies")

plt.xlabel("Movie features")

plt.ylabel("Movie features")

plt.show()
